# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'M86HCdicdWw39FBQmErT'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import json
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url="https://www.quandl.com/api/v3/datasets/WIKI/FB.json?column_index=4&start_date=2014-01-01&end_date=2014-01-01&collapse=monthly&transform=rdiff&api_key=M86HCdicdWw39FBQmErT"
r=requests.get(url)
json_data=r.json()

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
for key,value in json_data.items():
    print(value)
# Out:
# {'id': 9775687, 'dataset_code': 'FB', 'database_code': 'WIKI', 'name': 'Facebook Inc. (FB) Prices, Dividends, Splits and Trading Volume', 'description': "End of day open, high, low, close and volume, dividends and splits, and split/dividend adjusted open, high, low close and volume for Facebook, Inc. (FB). Ex-Dividend is non-zero on ex-dividend dates. Split Ratio is 1 on non-split dates. Adjusted prices are calculated per CRSP (www.crsp.com/products/documentation/crsp-calculations)\n\nThis data is in the public domain. You may copy, distribute, disseminate or include the data in other products for commercial and/or noncommercial purposes.\n\nThis data is part of Quandl's Wiki initiative to get financial data permanently into the public domain. Quandl relies on users like you to flag errors and provide data where data is wrong or missing. Get involved: connect@quandl.com\n", 'refreshed_at': '2018-03-27T21:46:11.036Z', 'newest_available_date': '2018-03-27', 'oldest_available_date': '20
# ...

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
url="https://www.quandl.com/api/v3/datasets/WIKI/FB.json?column_index=4&start_date=2017-01-01&end_date=2017-12-31&collapse=daily&transform=rdiff&api_key=M86HCdicdWw39FBQmErT"
r1=requests.get(url)
json_data=r1.json()

# %%
for key,value in json_data.items():
    print(value)
# Out:
# {'id': 9775687, 'dataset_code': 'FB', 'database_code': 'WIKI', 'name': 'Facebook Inc. (FB) Prices, Dividends, Splits and Trading Volume', 'description': "End of day open, high, low, close and volume, dividends and splits, and split/dividend adjusted open, high, low close and volume for Facebook, Inc. (FB). Ex-Dividend is non-zero on ex-dividend dates. Split Ratio is 1 on non-split dates. Adjusted prices are calculated per CRSP (www.crsp.com/products/documentation/crsp-calculations)\n\nThis data is in the public domain. You may copy, distribute, disseminate or include the data in other products for commercial and/or noncommercial purposes.\n\nThis data is part of Quandl's Wiki initiative to get financial data permanently into the public domain. Quandl relies on users like you to flag errors and provide data where data is wrong or missing. Get involved: connect@quandl.com\n", 'refreshed_at': '2018-03-27T21:46:11.036Z', 'newest_available_date': '2018-03-27', 'oldest_available_date': '20
# ...

# %%
print(type(json_data))
# Out:
# <class 'dict'>

# %%
list_of_price=json_data['dataset']['data']

# %%
print(list_of_price)
# Out:
# [['2017-12-29', -0.0082059352517984], ['2017-12-28', 0.0016889989866005], ['2017-12-27', 0.0092618898801068], ['2017-12-26', -0.0068284424379231], ['2017-12-22', -0.0014088475626937], ['2017-12-21', -0.0024734386418573], ['2017-12-20', -0.0090245668764972], ['2017-12-19', -0.0072447738082071], ['2017-12-18', 0.0035520035520035], ['2017-12-15', 0.010034194741858], ['2017-12-14', 0.00050476724621411], ['2017-12-13', 0.0075723327305606], ['2017-12-12', -0.011617515638963], ['2017-12-11', 0.00022346368715079], ['2017-12-08', -0.0063284112357055], ['2017-12-07', 0.023173917982506], ['2017-12-06', 0.018688885031534], ['2017-12-05', 0.007931416574328], ['2017-12-04', -0.020731010850942], ['2017-12-01', -0.011739473981262], ['2017-11-30', 0.011705590133044], ['2017-11-29', -0.039962723385594], ['2017-11-28', -0.0033327869748129], ['2017-11-27', 0.0013677645256593], ['2017-11-24', 0.010560070769061], ['2017-11-22', -0.0054437479379743], ['2017-11-21', 0.017455521987244], ['2017-11-20', -0.001
# ...

# %%
list_price=[]
for list_new in list_of_price:
    list_price.append(list_new[1])
    
print(list_price)
# Out:
# [-0.0082059352517984, 0.0016889989866005, 0.0092618898801068, -0.0068284424379231, -0.0014088475626937, -0.0024734386418573, -0.0090245668764972, -0.0072447738082071, 0.0035520035520035, 0.010034194741858, 0.00050476724621411, 0.0075723327305606, -0.011617515638963, 0.00022346368715079, -0.0063284112357055, 0.023173917982506, 0.018688885031534, 0.007931416574328, -0.020731010850942, -0.011739473981262, 0.011705590133044, -0.039962723385594, -0.0033327869748129, 0.0013677645256593, 0.010560070769061, -0.0054437479379743, 0.017455521987244, -0.0014525139664804, -0.0032852608719862, 0.0092160719303176, -0.00067389228954908, -0.0039156458018684, 0.0017370839403788, -0.0046848856664808, -0.0052704576976421, 0.00044402508741751, 0.0069863626201654, 0.0, -0.020475199824811, 0.014439631234033, 0.0010563184522155, 0.011187317292557, 0.042489597374436, 0.00017584994138336, -0.0069848661233994, 0.0030945291060898, -0.021202423134072, 0.0024060494958753, -0.0083508492870533, -0.00045426154108235
# ...

# %%
highest=max(list_price)
lowest=min(list_price)

# %%
print(highest,lowest)
# Out:
# 0.042489597374436 -0.044974785973965

# %%
print(len(list_price))
#for i in range(0,len())
# Out:
# 249

# %%
difference_list=[]
for i in range(0,len(list_price)-1):
    if i<len(list_price)-1:
        difference=abs(list_price[i]-list_price[i+1])
        difference_list.append(difference)
        
print(difference_list)
# Out:
# [0.0098949342383989, 0.007572890893506301, 0.0160903323180299, 0.0054195948752294, 0.0010645910791636, 0.006551128234639901, 0.001779793068290101, 0.0107967773602106, 0.0064821911898545, 0.00952942749564389, 0.00706756548434649, 0.0191898483695236, 0.01184097932611379, 0.006551874922856291, 0.029502329218211498, 0.004485032950971999, 0.010757468457206, 0.028662427425269997, 0.008991536869679998, 0.023445064114306, 0.051668313518638, 0.0366299364107811, 0.0047005515004722, 0.0091923062434017, 0.0160038187070353, 0.0228992699252183, 0.0189080359537244, 0.0018327469055058002, 0.0125013328023038, 0.00988996421986668, 0.0032417535123193206, 0.0056527297422472, 0.0064219696068596, 0.0005855720311613005, 0.00571448278505961, 0.006542337532747891, 0.0069863626201654, 0.020475199824811, 0.034914831058844, 0.0133833127818175, 0.0101309988403415, 0.031302280081879, 0.04231374743305264, 0.00716071606478276, 0.0100793952294892, 0.0242969522401618, 0.0236084726299473, 0.0107568987829286, 0.0078965
# ...

# %%
highest_diff=max(difference_list)

print(highest_diff)
# Out:
# 0.053202206616195
